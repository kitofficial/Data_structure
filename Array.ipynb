# %% [markdown]
# # Arrays

# %% [markdown]
# #Merge sort
#
# ![image.png](attachment:image.png)

# %%
def merge_sort(arr1,arr2,m,n):
    
    last = m+n-1
    m_new = m-1
    n_new = n-1
    
    while m_new>=0 and n_new>=0 :
        
        if arr1[m_new] > arr2[n_new]:
            arr1[last] = arr1[m_new]
            m_new = m_new - 1
        else:
            arr1[last] = arr2[n_new]
            n_new = n_new - 1
            
        last = last - 1
        
    # Copy any remaining elements from arr2
    while n_new >= 0:
        arr1[last] = arr2[n_new]
        n_new -= 1
        last -= 1

    
    return arr1

arr1 = [1,2,3,0,0,0]
arr2 = [2,5,6]
m = 3
n = 3
print(merge_sort(arr1,arr2,m,n))
# Out:
# [1, 2, 2, 3, 5, 6]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def remove_dup(arr):
    l = 0
    r = 0
    
    for r in range(1,len(arr)):
        if arr[l] != arr[r]:
            l = l+1
            arr[l] = arr[r]
     
        r = r+1
            
            
    return l+1
    
    

arr = arr = [1,1,1,2,2,2,3,4,5]

print(remove_dup(arr))
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def majorityElement(nums):

        count = 0
        res = 0

        for i in nums:

            if count == 0:
                res = i

            if i == res:
                count = count + 1

            else:
                count = count -1

        # Verify
        if nums.count(res) > len(nums)//2:
            return res
        else:
            return None  # no majority element
        
        return res

arr =  [2,2,1,1,1,2,2]

print(majorityElement(arr))
# Out:
# 2
